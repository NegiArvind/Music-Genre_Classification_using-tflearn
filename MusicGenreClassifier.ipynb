# %% [markdown]
# <a href="https://colab.research.google.com/github/NegiArvind/Music-Genre_Classification_using-tflearn/blob/master/MusicGenreClassifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Mounting the drive on google colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #### config.py

# %%
# Data Path
# For google colab
import os
driveLocation='drive/My Drive/MusicGenreClassification/'
# For PC
# driveLocation=''
rawDatasetPath=driveLocation+'data/RawDataset'
spectrogramsPath=driveLocation+'data/Spectograms'
slicesPath=driveLocation+'data/Slices'
datasetPath=driveLocation+'data/Dataset'
nbClasses=len(os.listdir(slicesPath))

#Spectrogram resolution
pixelPerSecond=50

#Slice Parameters
sliceSize=128

# Dataset parameter
validationRatio=0.3
testRatio=0.1

#Model parameters
batchSize=128
learningRate=0.001
nbEpoch=25

# %% [markdown]
# #### copyPaste.py
# it will copy some of the images and then put back into the same folder with prefix append on the filename.

# %%
# from config import slicesPath
# import os
# import shutil

# limit=1005

# def makeCopy(imageNames,times,genrePath):
  
#   prefixAppend=''
#   for i in range(times):
#     prefixAppend+='Z'
#   for imageName in imageNames:
#     print(prefixAppend)
#     shutil.copy(os.path.join(genrePath,imageName),os.path.join(genrePath,prefixAppend+'_'+imageName))
#     print(imageName)
#     if len(os.listdir(genrePath))>limit:
#       break
#   return len(os.listdir(genrePath))
	
# for genre in os.listdir(slicesPath):
# 	imageNames=os.listdir(os.path.join(slicesPath,genre))
# 	noOfFiles=len(imageNames)
# 	count=noOfFiles
# 	print(count)
# 	j=1
# 	while count<limit:
# 		print('chutiya')
# 		count=makeCopy(imageNames,j,os.path.join(slicesPath,genre))
# 		j+=1
# 		print(j)

# %% [markdown]
# #### create_spectrogram_from_audio.py

# %%
import os
# from config import rawDatasetPath
# from config import pixelPerSecond
# from config import spectrogramsPath
# from config import sliceSize
from subprocess import Popen,PIPE,STDOUT
from PIL import Image
# from config import slicesPath

# currentPath=os.getcwd()
# print(currentPath)
def createSpectrograms():
	
	genres=os.listdir(rawDatasetPath)
	for genre in genres:
		genrePath=os.path.join(rawDatasetPath,genre)
		print("Start Generating spectrogram for --{}-- genre".format(genre))
		musics=os.listdir(genrePath)
		for i,music in enumerate(musics):
			createSpectrogramFromAudio(os.path.join(genrePath,music),music,genre)
			print("Spectrogram Created {} / {}".format(i+1,len(musics)))

	# creating slices for every spectrogram
	print("Start creating slices..")
	createSlices()

def createSpectrogramFromAudio(musicPath,musicName,genre):

	if not os.path.exists(spectrogramsPath):
		os.makedirs(spectrogramsPath)
	spectrogramGenrePath=os.path.join(spectrogramsPath,genre)

	if not os.path.exists(spectrogramGenrePath):
		os.makedirs(spectrogramGenrePath)

	#This below command is used to create the spectrogram from the audio
	command='sox '+"'"+musicPath+"'"+' -n spectrogram -Y 200 -X {} -m -r -o "{}.png"'.format(pixelPerSecond,
		                      os.path.join(spectrogramGenrePath,musicName[:-4])) 
	#Popen class is used to run the command in the shell
	popen=Popen(command,shell=True,stdin=PIPE,stdout=PIPE,stderr=STDOUT,close_fds=True,cwd=currentPath)

	output,errors=popen.communicate()
	print(output)
	if errors:
		print(errors)

def createSlices():
	if not os.path.exists(slicesPath):
		os.makedirs(slicesPath)
	genres=os.listdir(spectrogramsPath)
	for genre in genres:
		genrePath=os.path.join(slicesPath,genre)
		spectrogramGenrePath=os.path.join(spectrogramsPath,genre)
		if not os.path.exists(genrePath):
			os.makedirs(genrePath)
		for imageName in os.listdir(spectrogramGenrePath):
			createSliceForSpectrogram(imageName,os.path.join(genrePath,imageName[:-4]),spectrogramGenrePath)

def createSliceForSpectrogram(spectrogramName,slicePath,spectrogramGenrePath):
	image=Image.open(os.path.join(spectrogramGenrePath,spectrogramName))
	print(image)
	width,height=image.size

	#compute approximately number of 128*128 samples
	nb_slices=int(width/sliceSize)
	for i in range(nb_slices):
		print("Creating slice: ",(i+1),"/",nb_slices," for ",spectrogramName)
		startPixel=i*sliceSize
		imageCrop=image.crop((startPixel,0,startPixel+sliceSize,sliceSize)) # croping the image into 128*128 pixel
		imageCrop.save(slicePath+"_{}.png".format(i+1)) 

#createSpectrograms()

# %% [markdown]
# #### datasetTools.py

# %%
# from config import slicesPath
from random import shuffle
# from config import datasetPath
import pickle
# from config import sliceSize
# from config import validationRatio
# from config import testRatio
import os
from PIL import Image
import numpy as np


def getDataset(sliceSize,validationRatio,testRatio,mode):

	if not os.path.exists(datasetPath+"/train_X.pkl"):
		createDatasetFromSlices(sliceSize,validationRatio,testRatio)
	else:
		print("Using existing data")
	return loadDataset(mode)


def loadDataset(mode):
	if mode=="train":
		print("Loading training and validation dataset...")
		with open("{}/train_X.pkl".format(datasetPath),'rb') as f:
			train_X=pickle.load(f)
		with open("{}/train_y.pkl".format(datasetPath),'rb') as f:
			train_y=pickle.load(f)
		with open("{}/validation_X.pkl".format(datasetPath),'rb') as f:
			validation_X=pickle.load(f)
		with open("{}/validation_y.pkl".format(datasetPath),'rb') as f:
			validation_y=pickle.load(f)
		print("Training and validation dataset loaded")
		return train_X,train_y,validation_X,validation_y

	else:
		print("Loading testing dataset...")
		with open("{}/test_X.pkl".format(datasetPath),'rb') as f:
			test_X=pickle.load(f)
		with open("{}/test_y.pkl".format(datasetPath),'rb') as f:
			test_y=pickle.load(f)
		print("Testing dataset loaded")
		return test_X,test_y


def createDatasetFromSlices(sliceSize,validationRatio,testRatio):
  
  print("Start Creating Dataset...")
  genres=os.listdir(slicesPath)
#   data=[]
#   for genre in genres:
#     for imageName in os.listdir(os.path.join(slicesPath,genre)):
#       imgData=getImageData(os.path.join(slicesPath,genre)+"/"+imageName,sliceSize)
#       label=[1 if genre==g else 0 for g in genres]
#       print(label)
#       data.append((imgData,label))
      
#   shuffle(data)
#   X,y=zip(*data)
  
#   #split data
#   validationNb=int(len(X)*validationRatio)
#   testNb=int(len(X)*testRatio)
#   trainNb=len(X)-(validationNb+testNb)
  
#   #prepare for Tflearn at the same time
#   train_X=np.array(X[:trainNb]).reshape([-1,sliceSize,sliceSize,1])
#   train_y=np.array(y[:trainNb])
#   validation_X=np.array(X[trainNb:trainNb+validationNb]).reshape(-1,sliceSize,sliceSize,1)
#   validation_y=np.array(y[trainNb:trainNb+validationNb])
#   test_X=np.array(X[-testNb:]).reshape(-1,sliceSize,sliceSize,1)
#   test_y=np.array(y[-testNb:])
#   print("Dataset successfully created ")
  
  trainSet=[]
  testSet=[]
  validationSet=[]
  
  for genre in genres:
    
    print(genres)
    print(genre)
    images=os.listdir(os.path.join(slicesPath,genre))
    shuffle(images)
    images=images[:1001] #Take only 1000 images
    nb_validation=int(len(images)*validationRatio)
    nb_test=int(len(images)*testRatio)
    print("images",len(images))
    print("validation",nb_validation)
    print("test",nb_test)
    
    i=0;
    for _ in range(len(images)-nb_validation-nb_test):
      print("train",str(i))
      imgData=getImageData(os.path.join(slicesPath,genre)+"/"+images[i],sliceSize)
      label=[1 if genre==g else 0 for g in genres]
      print(label)
      trainSet.append((imgData,label))
      i+=1
       
    for _ in range(nb_validation):
      print("validation",str(i))
      imgData=getImageData(os.path.join(slicesPath,genre)+"/"+images[i],sliceSize)
      label=[1 if genre==g else 0 for g in genres]
      print(label)
      validationSet.append((imgData,label))
      i+=1
      
    for _ in range(nb_test):
      print("test",str(i))
      imgData=getImageData(os.path.join(slicesPath,genre)+"/"+images[i],sliceSize)
      label=[1 if genre==g else 0 for g in genres]
      print(label)
      testSet.append((imgData,label))
      i+=1
      
  train_X,train_y=zip(*trainSet)
  validation_X,validation_y=zip(*validationSet)
  test_X,test_y=zip(*testSet)
  
  train_X=np.array(train_X).reshape(-1,sliceSize,sliceSize,1)
  train_y=np.array(train_y)
  validation_X=np.array(validation_X).reshape(-1,sliceSize,sliceSize,1)
  validation_y=np.array(validation_y)
  test_X=np.array(test_X).reshape(-1,sliceSize,sliceSize,1)
  test_y=np.array(test_y)
  print("Dataset successfully created ")
  
  # save the dataset 
  saveDataset(train_X,train_y,validation_X,validation_y,test_X,test_y)

def saveDataset(train_X,train_y,validation_X,validation_y,test_X,test_y):
	if not os.path.exists(datasetPath):
		os.makedirs(datasetPath)

	print("Start Saving the dataset...")
	with open("{}/train_X.pkl".format(datasetPath),'wb') as f:
		pickle.dump(train_X,f)
	with open("{}/train_y.pkl".format(datasetPath),'wb') as f:
		pickle.dump(train_y,f)
	with open("{}/validation_X.pkl".format(datasetPath),'wb') as f:
		pickle.dump(validation_X,f)
	with open("{}/validation_y.pkl".format(datasetPath),'wb') as f:
		pickle.dump(validation_y,f)
	with open("{}/test_X.pkl".format(datasetPath),'wb') as f:
		pickle.dump(test_X,f)
	with open("{}/test_y.pkl".format(datasetPath),'wb') as f:
		pickle.dump(test_y,f)

	print("Dataset successfully Saved")


def getImageData(imagePath,imageSize):
	image=Image.open(imagePath)
	image=image.resize((imageSize,imageSize),resample=Image.ANTIALIAS)
	image=np.asarray(image,dtype=np.uint8).reshape(imageSize,imageSize,1)
	image=image/255
	return image

# %% [markdown]
# #### Installing tflearn

# %%
# !pip install tflearn
# Out:
# Requirement already satisfied: tflearn in /usr/local/lib/python3.6/dist-packages (0.3.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from tflearn) (1.14.6)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from tflearn) (1.11.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from tflearn) (4.0.0)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from Pillow->tflearn) (0.46)

# %% [markdown]
# #### model.py

# %%
import tflearn
from tflearn.layers.conv import conv_2d,max_pool_2d
from tflearn.layers.core import input_data,dropout,fully_connected
from tflearn.layers.estimator import regression

def createModel(nbClasses,imageSize):
  
  print("Creating model...")
  input_layer=input_data(shape=[None,imageSize,imageSize,1],name='input')
  
  convNetwork=conv_2d(incoming=input_layer,nb_filter=32,filter_size=3,activation='elu',weights_init='Xavier')
  convNetwork=max_pool_2d(incoming=convNetwork,kernel_size=[2,2])
  
  convNetwork=conv_2d(incoming=convNetwork,nb_filter=64,filter_size=3,activation='elu',weights_init='Xavier')
  convNetwork=max_pool_2d(incoming=convNetwork,kernel_size=[2,2])
  
  convNetwork=conv_2d(incoming=convNetwork,nb_filter=128,filter_size=3,activation='elu',weights_init='Xavier')
  convNetwork=max_pool_2d(incoming=convNetwork,kernel_size=[2,2])
  
  convNetwork=conv_2d(incoming=convNetwork,nb_filter=256,filter_size=3,activation='elu',weights_init='Xavier')
  convNetwork=max_pool_2d(incoming=convNetwork,kernel_size=[2,2])
  
  convNetwork=conv_2d(incoming=convNetwork,nb_filter=512,filter_size=3,activation='elu',weights_init='Xavier')
  convNetwork=max_pool_2d(incoming=convNetwork,kernel_size=[2,2])
  
  convNetwork=fully_connected(incoming=convNetwork,n_units=1024,activation='elu') # 1024 nodes in hidden layer
  convNetwork=dropout(incoming=convNetwork,keep_prob=0.5)
  
  convNetwork=fully_connected(incoming=convNetwork,n_units=512,activation='elu') # 1024 nodes in hidden layer
  convNetwork=dropout(incoming=convNetwork,keep_prob=0.5)
  
  convNetwork=fully_connected(incoming=convNetwork,n_units=nbClasses,activation='softmax') # nbClasses nodes in output layer
  convNetwork=regression(incoming=convNetwork,metric='accuracy',optimizer='rmsprop',loss='categorical_crossentropy') # it will optimize the loss
  
  model=tflearn.DNN(convNetwork)
  print("Model successfully created! ")
  return model

# %% [markdown]
# #### train_and_test_the_model.py

# %%
import argparse
# from model import createModel
# from config import validationRatio,testRatio,sliceSize,nbEpoch,batchSize
# from create_spectrogram_from_audio import createSpectrograms
# from config import slicesPath
# from datasetTools import getDataset
import os
import random
import string 
import numpy as np 


# parser=argparse.ArgumentParser()
# parser.add_argument("mode",help="Train or tests the CNN",nargs='+',choices=["train","test","slice"])
# args=parser.parse_args()

print("--------------------------")
print("| ** Config ** ")
print("| Validation ratio: {}".format(validationRatio))
print("| Test ratio: {}".format(testRatio))
print("| Slice size: {}".format(sliceSize))
print("--------------------------")

type='test'

if "slice"==type:
	print("inside slice")
	createSpectrograms() # it will create slices for every spectrograms
	sys.exit()

nbClasses=len(os.listdir(slicesPath))

#create model
model=createModel(nbClasses,sliceSize)

if "train"==type:
  #create or load new dataset
  train_X,train_y,validation_X,validation_y=getDataset(sliceSize,validationRatio,testRatio,mode="train")
  
  #Define run id for graphs
  run_id = "MusicGenres - "+str(batchSize)+" "+''.join(random.SystemRandom().
                                                       choice(string.ascii_uppercase) for _ in range(nbClasses))
  
  #Train the model
  print(len(train_X))
  print(len(train_y))
  print(len(validation_X))
  print(len(validation_y))
  model.fit(train_X,train_y,n_epoch=nbEpoch,batch_size=batchSize,shuffle=True,
            validation_set=(validation_X,validation_y),snapshot_step=100,show_metric=True,run_id=run_id)
  
  print("Model Trained")
  
  #Save trained model
  print("Saving the weights")
  if not os.path.exists(driveLocation+'TrainedModel'):
    os.makedirs(driveLocation+'TrainedModel')
  model.save(driveLocation+'TrainedModel/genreClassifierModel.tflearn')
  print("Weight saved!")

if "test"==type:
  
  #load the test Dataset
  test_X,test_y=getDataset(sliceSize,validationRatio,testRatio,mode="test")
  
  #Load the weights(model)
  print("Loading weights...")
  model.load(driveLocation+'TrainedModel/genreClassifierModel.tflearn')
  print('weights loaded!')
  
  genres=os.listdir(slicesPath)
  
  predictions=model.predict(test_X) # returns the list of prediction
  best_class_indices=np.argmax(predictions,axis=1)
  best_class_probabilities=predictions[np.arange(len(best_class_indices)),best_class_indices]
  
  y=np.argmax(test_y,axis=1)
  for i in range(len(best_class_indices)):
    genreType=''
    if best_class_probabilities[i]>0.52:
      genreType=genres[best_class_indices[i]]
    else:
      genreType='Unknown'
    print('%4d  %s: %.3f  %s' % (i,genreType, best_class_probabilities[i],genres[y[i]]))
    
  accuracy=np.mean(np.equal(best_class_indices,y))
  print("Accuracy : {}".format(accuracy))
  testAccuracy=model.evaluate(test_X,test_y)[0]
  print("Test Accuracy : {}".format(testAccuracy))
# Out:
# --------------------------
# | ** Config **
# | Validation ratio: 0.3
# | Test ratio: 0.1
# | Slice size: 128
# --------------------------
# Creating model...
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tflearn/objectives.py:66: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# Model successfully created!
# Using existing data
# Loading testing dataset...
# Testing dataset loaded
# Loading weights...
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/MusicGenreClassification/TrainedModel/genreClassifierModel.tflearn
# weights loaded!
#    0  pop: 0.815  rock
#    1  Unknown: 0.421  rock
#    2  rock: 0.955  rock
#    3  Unknown: 0.467  rock
#    4  rock: 0.995  rock
#    5  Unknown: 0.400  rock
#    6  rock: 0.997  rock
#    7  jazz: 1.000  rock
#    8  rock: 0.997  rock
#    9  jazz: 1.000  rock
#   10  funksoulrnb: 0.656  rock
#   11  folkcountry: 0.775  rock
#   12  folkcountry: 0.786  rock
#   13  rock: 0.999  rock
#   14  electronic: 0.901  rock
#   15  raphiphop: 0.991  rock
#   16  rock: 0.989  rock
#   17  alternative: 0.996  rock
#   18  rock: 0.998  rock
#   19  rock: 0.996  rock
#   20  rock: 0.998  rock
#   21  rock: 0.997  rock
#   22  funksoulrnb: 0.619  rock
#   23  raphiphop: 0.980  rock
#   24  raphiphop: 0.957  rock
#   25  folkcountry: 0.737  rock
#   26  pop: 0.996  rock
#   27  Unknown: 0.358  rock
#   28  rock: 0.993  rock
#   29  rock: 1.000  rock
#   30  jazz: 1.000  rock
#   31  folkcountry: 0.597  rock
#   32  rock: 0.952  rock
#   33  rock: 0.900  rock
#   34  rock: 0.595  rock
#   35  raphiphop: 0.974  rock
#   36  rock: 0.999  rock
#   37  Unknown: 0.413  rock
#   38  rock: 0.929  rock
#   39  alternative: 0.867  rock
#   40  rock: 0.689  rock
#   41  alternative: 0.678  rock
#   42  rock: 1.000  rock
#   43  alternative: 0.831  rock
#   44  folkcountry: 0.909  rock
#   45  jazz: 0.981  rock
#   46  rock: 1.000  rock
#   47  blues: 0.796  rock
#   48  rock: 0.980  rock
#   49  Unknown: 0.517  rock
#   50  folkcountry: 0.553  rock
#   51  folkcountry: 0.989  rock
#   52  blues: 0.995  rock
#   53  rock: 1.000  rock
#   54  folkcountry: 0.997  rock
#   55  folkcountry: 0.898  rock
#   56  folkcountry: 0.809  rock
#   57  rock: 0.986  rock
#   58  raphiphop: 0.989  rock
#   59  rock: 0.609  rock
#   60  rock: 0.998  rock
#   61  blues: 0.612  rock
#   62  rock: 0.991  rock
#   63  folkcountry: 0.681  rock
#   64  folkcountry: 0.642  rock
#   65  rock: 0.922  rock
#   66  folkcountry: 0.966  rock
#   67  folkcountry: 0.690  rock
#   68  rock: 0.994  rock
#   69  alternative: 0.579  rock
#   70  Unknown: 0.471  rock
#   71  rock: 0.826  rock
#   72  rock: 0.992  rock
#   73  Unknown: 0.440  rock
#   74  rock: 0.968  rock
#   75  rock: 1.000  rock
#   76  rock: 0.823  rock
#   77  pop: 0.607  rock
#   78  Unknown: 0.484  rock
#   79  jazz: 0.834  rock
#   80  folkcountry: 1.000  rock
#   81  raphiphop: 0.888  rock
#   82  folkcountry: 0.538  rock
#   83  rock: 0.995  rock
#   84  Unknown: 0.453  rock
#   85  Unknown: 0.518  rock
#   86  rock: 0.724  rock
#   87  rock: 0.832  rock
#   88  rock: 0.910  rock
#   89  Unknown: 0.500  rock
#   90  folkcountry: 0.711  rock
#   91  rock: 0.890  rock
#   92  Unknown: 0.481  rock
#   93  funksoulrnb: 0.802  rock
#   94  rock: 0.528  rock
#   95  jazz: 0.543  rock
#   96  folkcountry: 0.885  rock
#   97  rock: 1.000  rock
#   98  rock: 0.785  rock
#   99  rock: 0.879  rock
#  100  electronic: 1.000  electronic
#  101  electronic: 1.000  electronic
#  102  electronic: 1.000  electronic
#  103  Unknown: 0.456  electronic
#  104  electronic: 0.991  electronic
#  105  Unknown: 0.456  electronic
#  106  electronic: 0.994  electronic
#  107  electronic: 1.000  electronic
#  108  electronic: 1.000  electronic
#  109  electronic: 1.000  electronic
#  110  electronic: 1.000  electronic
#  111  electronic: 0.999  electronic
#  112  electronic: 0.997  electronic
#  113  electronic: 0.999  electronic
#  114  electronic: 0.999  electronic
#  115  electronic: 1.000  electronic
#  116  electronic: 0.990  electronic
#  117  electronic: 0.997  electronic
#  118  electronic: 1.000  electronic
#  351  raphiphop: 0.990  raphiphop
#  352  funksoulrnb: 0.887  raphiphop
#  353  raphiphop: 0.931  raphiphop
#  354  raphiphop: 0.879  raphiphop
#  355  raphiphop: 0.990  raphiphop
#  356  raphiphop: 0.663  raphiphop
#  357  raphiphop: 0.960  raphiphop
#  358  raphiphop: 0.996  raphiphop
#  359  raphiphop: 0.991  raphiphop
#  360  raphiphop: 1.000  raphiphop
#  361  folkcountry: 0.622  raphiphop
#  362  jazz: 0.520  raphiphop
#  363  raphiphop: 0.903  raphiphop
#  364  jazz: 0.990  raphiphop
#  365  raphiphop: 0.995  raphiphop
#  366  raphiphop: 0.904  raphiphop
#  367  raphiphop: 1.000  raphiphop
#  368  blues: 0.972  raphiphop
#  369  raphiphop: 0.956  raphiphop
#  370  raphiphop: 1.000  raphiphop
#  371  raphiphop: 0.868  raphiphop
#  372  raphiphop: 0.967  raphiphop
#  373  raphiphop: 0.999  raphiphop
#  374  raphiphop: 0.996  raphiphop
#  375  raphiphop: 0.998  raphiphop
#  376  raphiphop: 0.997  raphiphop
#  377  raphiphop: 0.934  raphiphop
#  378  raphiphop: 1.000  raphiphop
#  379  raphiphop: 0.988  raphiphop
#  380  raphiphop: 0.999  raphiphop
#  381  raphiphop: 1.000  raphiphop
#  382  raphiphop: 0.969  raphiphop
#  383  raphiphop: 0.967  raphiphop
#  384  raphiphop: 0.811  raphiphop
#  385  raphiphop: 0.997  raphiphop
#  386  raphiphop: 1.000  raphiphop
#  387  raphiphop: 1.000  raphiphop
#  388  raphiphop: 0.996  raphiphop
#  389  rock: 0.802  raphiphop
#  390  raphiphop: 1.000  raphiphop
#  391  raphiphop: 0.995  raphiphop
#  392  raphiphop: 0.997  raphiphop
#  393  raphiphop: 1.000  raphiphop
#  394  raphiphop: 0.787  raphiphop
#  395  raphiphop: 0.819  raphiphop
#  396  raphiphop: 1.000  raphiphop
#  397  jazz: 0.723  raphiphop
#  398  Unknown: 0.504  raphiphop
#  399  raphiphop: 0.960  raphiphop
#  400  pop: 0.996  pop
#  401  pop: 1.000  pop
#  402  folkcountry: 0.672  pop
#  403  pop: 1.000  pop
#  404  pop: 1.000  pop
#  405  pop: 1.000  pop
#  406  pop: 1.000  pop
#  407  pop: 0.951  pop
#  408  Unknown: 0.489  pop
#  409  folkcountry: 0.948  pop
#  410  raphiphop: 0.985  pop
#  411  pop: 1.000  pop
#  412  pop: 1.000  pop
#  413  folkcountry: 0.754  pop
#  414  pop: 1.000  pop
#  415  folkcountry: 0.999  pop
#  416  folkcountry: 0.564  pop
#  417  pop: 1.000  pop
#  418  folkcountry: 0.957  pop
#  419  Unknown: 0.451  pop
#  420  pop: 0.999  pop
#  421  pop: 1.000  pop
#  422  pop: 1.000  pop
#  423  Unknown: 0.455  pop
#  424  pop: 1.000  pop
#  425  pop: 1.000  pop
#  426  jazz: 0.569  pop
#  427  folkcountry: 0.999  pop
#  428  pop: 0.999  pop
#  429  pop: 0.985  pop
#  430  folkcountry: 0.705  pop
#  431  pop: 0.996  pop
#  432  pop: 1.000  pop
#  433  pop: 0.999  pop
#  434  pop: 1.000  pop
#  435  raphiphop: 0.609  pop
#  436  pop: 1.000  pop
#  437  pop: 1.000  pop
#  438  rock: 0.999  pop
#  439  pop: 1.000  pop
#  440  Unknown: 0.511  pop
#  441  pop: 1.000  pop
#  442  jazz: 0.578  pop
#  443  raphiphop: 0.609  pop
#  444  pop: 1.000  pop
#  445  pop: 0.999  pop
#  446  pop: 1.000  pop
#  447  pop: 0.992  pop
#  448  pop: 1.000  pop
#  449  pop: 1.000  pop
#  450  pop: 1.000  pop
#  451  pop: 0.999  pop
#  452  folkcountry: 1.000  pop
#  453  pop: 0.999  pop
#  454  pop: 1.000  pop
#  455  pop: 1.000  pop
#  456  pop: 1.000  pop
#  457  pop: 1.000  pop
#  458  pop: 1.000  pop
#  459  pop: 1.000  pop
#  460  pop: 0.894  pop
#  461  pop: 1.000  pop
#  462  pop: 0.999  pop
#  463  pop: 0.999  pop
#  464  raphiphop: 0.570  pop
#  465  pop: 0.999  pop
#  466  pop: 1.000  pop
#  467  raphiphop: 0.913  pop
#  468  pop: 0.999  pop
#  469  pop: 0.997  pop
#  470  pop: 1.000  pop
#  471  pop: 0.858  pop
#  472  pop: 0.999  pop
#  473  pop: 1.000  pop
#  474  pop: 1.000  pop
#  475  pop: 0.999  pop
#  476  pop: 0.991  pop
#  477  pop: 0.969  pop
#  478  pop: 1.000  pop
#  479  folkcountry: 0.914  pop
#  480  pop: 0.997  pop
#  481  pop: 1.000  pop
#  482  pop: 1.000  pop
#  483  pop: 0.583  pop
#  484  Unknown: 0.455  pop
#  485  pop: 1.000  pop
#  486  Unknown: 0.485  pop
#  487  pop: 0.999  pop
#  488  pop: 1.000  pop
#  489  pop: 0.998  pop
#  490  pop: 1.000  pop
#  491  jazz: 0.569  pop
#  492  pop: 0.989  pop
#  493  folkcountry: 0.938  pop
#  494  pop: 1.000  pop
#  495  rock: 0.972  pop
#  496  pop: 1.000  pop
#  497  pop: 0.996  pop
#  498  folkcountry: 0.926  pop
#  499  pop: 1.000  pop
#  500  blues: 1.000  blues
#  501  blues: 1.000  blues
#  502  blues: 1.000  blues
#  503  blues: 0.833  blues
#  504  blues: 1.000  blues
#  505  blues: 1.000  blues
#  506  blues: 0.990  blues
#  507  blues: 1.000  blues
#  508  blues: 1.000  blues
#  509  blues: 1.000  blues
#  510  blues: 1.000  blues
#  511  Unknown: 0.500  blues
#  512  blues: 0.986  blues
#  513  blues: 1.000  blues
#  514  blues: 1.000  blues
#  515  blues: 0.999  blues
#  516  blues: 0.986  blues
#  517  blues: 0.862  blues
#  518  blues: 1.000  blues
#  519  funksoulrnb: 0.789  blues
#  520  blues: 1.000  blues
#  521  rock: 0.929  blues
#  522  blues: 1.000  blues
#  523  blues: 1.000  blues
#  524  blues: 1.000  blues
#  525  blues: 1.000  blues
#  674  funksoulrnb: 1.000  funksoulrnb
#  675  funksoulrnb: 1.000  funksoulrnb
#  676  funksoulrnb: 1.000  funksoulrnb
#  677  funksoulrnb: 1.000  funksoulrnb
#  678  funksoulrnb: 1.000  funksoulrnb
#  679  funksoulrnb: 1.000  funksoulrnb
#  680  funksoulrnb: 0.980  funksoulrnb
#  681  funksoulrnb: 1.000  funksoulrnb
#  682  funksoulrnb: 0.758  funksoulrnb
#  683  funksoulrnb: 0.998  funksoulrnb
#  684  funksoulrnb: 1.000  funksoulrnb
#  685  funksoulrnb: 1.000  funksoulrnb
#  686  funksoulrnb: 1.000  funksoulrnb
#  687  funksoulrnb: 1.000  funksoulrnb
#  688  funksoulrnb: 1.000  funksoulrnb
#  689  funksoulrnb: 1.000  funksoulrnb
#  690  funksoulrnb: 1.000  funksoulrnb
#  691  funksoulrnb: 1.000  funksoulrnb
#  692  funksoulrnb: 0.999  funksoulrnb
#  693  funksoulrnb: 0.999  funksoulrnb
#  694  funksoulrnb: 1.000  funksoulrnb
#  695  funksoulrnb: 1.000  funksoulrnb
#  696  funksoulrnb: 1.000  funksoulrnb
#  697  funksoulrnb: 1.000  funksoulrnb
#  698  funksoulrnb: 1.000  funksoulrnb
#  699  funksoulrnb: 1.000  funksoulrnb
#  700  alternative: 1.000  alternative
#  701  alternative: 0.899  alternative
#  702  alternative: 1.000  alternative
#  703  alternative: 1.000  alternative
#  704  alternative: 1.000  alternative
#  705  alternative: 0.968  alternative
#  706  Unknown: 0.518  alternative
#  707  alternative: 1.000  alternative
#  708  alternative: 1.000  alternative
#  709  alternative: 0.547  alternative
#  710  alternative: 1.000  alternative
#  711  alternative: 0.999  alternative
#  712  alternative: 1.000  alternative
#  713  alternative: 0.927  alternative
#  714  alternative: 0.999  alternative
#  715  alternative: 1.000  alternative
#  716  alternative: 0.882  alternative
#  717  folkcountry: 0.993  alternative
#  718  alternative: 1.000  alternative
#  719  alternative: 0.999  alternative
#  720  alternative: 0.999  alternative
#  721  blues: 0.780  alternative
#  722  electronic: 0.808  alternative
#  723  raphiphop: 0.643  alternative
#  724  alternative: 0.999  alternative
#  725  alternative: 0.998  alternative
#  726  alternative: 0.773  alternative
#  727  alternative: 0.928  alternative
#  728  alternative: 1.000  alternative
#  729  alternative: 0.994  alternative
#  730  alternative: 0.571  alternative
#  731  alternative: 1.000  alternative
#  732  alternative: 0.728  alternative
#  733  jazz: 0.619  alternative
#  734  blues: 0.931  alternative
#  735  alternative: 1.000  alternative
#  736  alternative: 0.989  alternative
#  737  alternative: 1.000  alternative
#  738  alternative: 0.999  alternative
#  739  blues: 0.985  alternative
#  740  alternative: 0.986  alternative
#  741  rock: 0.793  alternative
#  742  alternative: 1.000  alternative
#  743  Unknown: 0.319  alternative
#  744  alternative: 0.833  alternative
#  745  alternative: 0.999  alternative
#  746  folkcountry: 0.995  alternative
#  747  alternative: 0.889  alternative
#  748  pop: 0.548  alternative
#  749  alternative: 1.000  alternative
#  750  jazz: 0.973  alternative
#  751  alternative: 0.984  alternative
#  752  folkcountry: 0.998  alternative
#  753  alternative: 1.000  alternative
#  754  alternative: 0.972  alternative
#  755  alternative: 0.963  alternative
#  756  alternative: 1.000  alternative
#  757  alternative: 1.000  alternative
#  758  alternative: 1.000  alternative
#  759  alternative: 0.999  alternative
#  760  alternative: 1.000  alternative
#  761  alternative: 0.565  alternative
#  762  alternative: 0.984  alternative
#  763  folkcountry: 0.555  alternative
#  764  alternative: 1.000  alternative
#  765  alternative: 0.998  alternative
#  766  pop: 0.548  alternative
#  767  alternative: 0.820  alternative
#  768  Unknown: 0.460  alternative
#  769  folkcountry: 0.810  alternative
#  770  alternative: 0.994  alternative
#  771  alternative: 0.998  alternative
#  772  alternative: 0.770  alternative
#  773  alternative: 1.000  alternative
#  774  alternative: 0.999  alternative
#  775  alternative: 1.000  alternative
#  776  folkcountry: 0.794  alternative
#  777  alternative: 1.000  alternative
#  778  alternative: 1.000  alternative
#  779  alternative: 0.894  alternative
#  780  alternative: 1.000  alternative
#  781  electronic: 0.991  alternative
#  782  alternative: 1.000  alternative
#  783  alternative: 0.996  alternative
#  784  folkcountry: 0.959  alternative
#  785  alternative: 1.000  alternative
#  786  alternative: 0.959  alternative
#  787  alternative: 0.571  alternative
#  788  alternative: 1.000  alternative
#  789  alternative: 1.000  alternative
#  790  blues: 0.825  alternative
#  791  alternative: 0.995  alternative
#  792  alternative: 0.994  alternative
#  793  alternative: 1.000  alternative
#  794  alternative: 1.000  alternative
#  795  alternative: 1.000  alternative
#  796  alternative: 0.999  alternative
#  797  alternative: 1.000  alternative
#  798  alternative: 0.995  alternative
#  799  blues: 0.825  alternative
#  800  raphiphop: 1.000  jazz
#  801  pop: 0.985  jazz
#  802  jazz: 0.999  jazz
#  803  jazz: 0.817  jazz
#  804  raphiphop: 0.910  jazz
#  805  pop: 0.719  jazz
#  806  Unknown: 0.474  jazz
#  807  alternative: 0.987  jazz
#  808  folkcountry: 0.632  jazz
#  809  jazz: 0.553  jazz
#  810  funksoulrnb: 0.878  jazz
#  811  jazz: 0.942  jazz
#  812  jazz: 0.998  jazz
#  813  jazz: 0.959  jazz
#  814  jazz: 0.980  jazz
#  815  jazz: 0.822  jazz
#  816  pop: 0.756  jazz
#  817  electronic: 0.962  jazz
#  818  blues: 0.971  jazz
#  819  jazz: 0.999  jazz
#  820  pop: 0.537  jazz
#  821  electronic: 0.758  jazz
#  822  Unknown: 0.515  jazz
#  823  folkcountry: 0.982  jazz
#  824  jazz: 0.654  jazz
#  825  folkcountry: 0.616  jazz
#  826  jazz: 0.873  jazz
#  827  raphiphop: 0.897  jazz
#  828  folkcountry: 0.830  jazz
#  829  folkcountry: 0.894  jazz
#  830  electronic: 0.957  jazz
#  831  jazz: 0.784  jazz
#  832  pop: 0.886  jazz
#  833  jazz: 0.945  jazz
#  834  jazz: 1.000  jazz
#  835  raphiphop: 0.925  jazz
#  836  jazz: 0.983  jazz
#  837  raphiphop: 0.995  jazz
#  838  jazz: 0.796  jazz
#  839  jazz: 0.910  jazz
#  840  jazz: 1.000  jazz
#  841  jazz: 0.994  jazz
#  842  rock: 0.993  jazz
#  843  jazz: 0.984  jazz
#  844  jazz: 0.993  jazz
#  845  jazz: 0.968  jazz
#  846  Unknown: 0.479  jazz
#  847  rock: 0.735  jazz
#  848  jazz: 0.651  jazz
#  849  folkcountry: 0.732  jazz
#  850  Unknown: 0.468  jazz
#  851  jazz: 0.972  jazz
#  852  jazz: 0.534  jazz
#  853  jazz: 0.525  jazz
#  854  jazz: 0.982  jazz
#  855  jazz: 0.947  jazz
#  856  raphiphop: 0.969  jazz
#  857  jazz: 1.000  jazz
#  858  blues: 0.948  jazz
#  859  jazz: 0.648  jazz
#  860  jazz: 0.933  jazz
#  861  jazz: 0.982  jazz
#  862  jazz: 0.677  jazz
#  863  jazz: 0.994  jazz
#  864  Unknown: 0.513  jazz
#  865  Unknown: 0.463  jazz
#  866  blues: 0.906  jazz
#  867  jazz: 0.828  jazz
#  868  pop: 0.999  jazz
#  869  raphiphop: 1.000  jazz
#  870  jazz: 0.758  jazz
#  871  folkcountry: 0.999  jazz
#  872  jazz: 1.000  jazz
#  873  jazz: 0.999  jazz
#  874  raphiphop: 0.994  jazz
#  875  jazz: 1.000  jazz
#  876  jazz: 0.956  jazz
#  877  raphiphop: 0.990  jazz
#  878  raphiphop: 0.685  jazz
#  879  pop: 0.933  jazz
#  880  jazz: 0.748  jazz
#  881  jazz: 1.000  jazz
#  882  jazz: 0.833  jazz
#  883  folkcountry: 0.893  jazz
#  884  folkcountry: 0.565  jazz
#  885  jazz: 1.000  jazz
#  886  pop: 0.997  jazz
#  887  jazz: 0.798  jazz
#  888  raphiphop: 0.939  jazz
#  889  alternative: 0.760  jazz
#  890  rock: 0.940  jazz
#  891  raphiphop: 0.999  jazz
#  892  raphiphop: 1.000  jazz
#  893  jazz: 1.000  jazz
#  894  Unknown: 0.466  jazz
#  895  folkcountry: 0.715  jazz
#  896  jazz: 0.966  jazz
#  897  raphiphop: 0.983  jazz
#  898  raphiphop: 0.738  jazz
#  899  rock: 0.672  jazz
# Accuracy : 0.7288888888888889
# Test Accuracy : 0.7288888888888889

# %% [markdown]
# #### Installation of sox
# To create spectrogram from a music we need to install sox.

# %%
# !apt-get install sox libsox-dev libsox-fmt-all
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libsox-dev is already the newest version (14.4.2-3).
# libsox-fmt-all is already the newest version (14.4.2-3).
# sox is already the newest version (14.4.2-3).
# 0 upgraded, 0 newly installed, 0 to remove and 3 not upgraded.

# %% [markdown]
# #### predict_the_genre_of_music.py
# In this script you will enter the name of the music and it will tell you the genre of the music.
# First, we will get the spectrogram from the music and then we will divide the spectrogram into fixed sliceSize.
# we will pass the slice images of spectrogram into cnn and then it will return the probablity of founding the image in a particular class.
# We will select that genre which will get higher vote.

# %%
import argparse
# from model import createModel
# from config import validationRatio,testRatio,sliceSize,nbEpoch,batchSize
# from create_spectrogram_from_audio import createSpectrograms
# from config import slicesPath
# from datasetTools import getDataset
import os
import random
import string 
import numpy as np 
# from config import sliceSize
from collections import Counter

currentPath=os.getcwd()

def createSpectrogramForOneMusic(musicPath,sliceSize):
  
  temp=musicPath.split('/')
  musicName=temp[len(temp)-1]
  musicName=musicName[:-4]
  command='sox '+"'"+musicPath+"'"+' -n spectrogram -Y 200 -X {} -m -r -o "{}.png"'.format(pixelPerSecond,
                                                                                           driveLocation+musicName)
  
  popen=Popen(command,shell=True,stdin=PIPE,stdout=PIPE,stderr=STDOUT,close_fds=True,cwd=currentPath)
  
  output,errors=popen.communicate()
  print(output)
  if errors:
    print(errors)
    
  image=Image.open(driveLocation+musicName+".png") #Opening the image
  width,height=image.size
  nbSamples=int(width/sliceSize)
  os.remove(driveLocation+musicName+".png") # Removing the image(no need of it)
  slicedImages=[]
  for i in range(nbSamples):
    print("Creating slice: ",(i+1),"/",nbSamples," for ",musicName+'.png')
    startPixel=i*sliceSize
    imageCrop=image.crop((startPixel,0,startPixel+sliceSize,sliceSize)) # croping the image into 128*128 pixel
    slicedImages.append(imageCrop)
    
  return slicedImages

def getImageDataFromSlice(musicPath,imageSize):
  slicedImages=createSpectrogramForOneMusic(musicPath,imageSize)
  imageData=[]
  for image in slicedImages:
    image=image.resize((imageSize,imageSize),resample=Image.ANTIALIAS)
    image=np.asarray(image,dtype=np.uint8).reshape(imageSize,imageSize,1)
    image=image/255
    imageData.append(image)
  return imageData

def predictGenre(musicPath,imageSize):
#   model=createModel(nbClasses,imageSize)
  imagesData=getImageDataFromSlice(musicPath,imageSize)
  #Load the weights(model)
  print("Loading weights...")
  model.load(driveLocation+'TrainedModel/genreClassifierModel.tflearn')
  print('weights loaded!')
  
  predictions=model.predict(imagesData) # returns the list of prediction
  best_class_indices=np.argmax(predictions,axis=1)
  best_class_probabilities=predictions[np.arange(len(best_class_indices)),best_class_indices]
  
  genres=os.listdir(slicesPath)
  count=0
  most_common,num_most_common = Counter(best_class_indices).most_common(1)[0] # return value which repeate most and number of times it repeates
  
  sum=0
  if num_most_common>1:
    for i in range(len(best_class_indices)):
      if most_common==best_class_indices[i]:
        sum+=best_class_probabilities[i]
    meanProbability=sum/len(best_class_indices)
    print('Higher vote ---  %s:  %.3f' % (genres[most_common],meanProbability*100))
    
  else:
    print('maximum prob --- %s:  %.3f ' %(genres[np.argmax(best_class_probabilities)],best_class_probabilities[np.argmax[best_class_probabilities]]*100))
    
if __name__=='__main__':
  predictGenre(driveLocation+'musics/22-Lonely.mp3',sliceSize)
# Out:
# b''
# Creating slice:  1 / 3  for  22-Lonely.png
# Creating slice:  2 / 3  for  22-Lonely.png
# Creating slice:  3 / 3  for  22-Lonely.png
# Loading weights...
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/MusicGenreClassification/TrainedModel/genreClassifierModel.tflearn
# weights loaded!
# Higher vote ---  electronic:  88.954
